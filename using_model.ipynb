# %%
# imports
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from PIL import Image
import numpy as np

# AS USED IN TRAINING
class CNN(nn.Module):
    def __init__(self, in_channel=3, num_classes=200):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channel, out_channels=8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
        self.pool = nn.MaxPool2d(kernel_size=(2, 2))
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
        self.fc1 = nn.Linear(16 * 8 * 8, num_classes)
        
    def forward(self, x):
        x = nn.functional.relu(self.conv1(x))
        x = self.pool(x)
        x = nn.functional.relu(self.conv2(x))
        x = self.pool(x)
        x = x.reshape(x.shape[0], -1)
        x = self.fc1(x)
        return x

def load_model(checkpoint_path, num_classes):
    model = CNN(num_classes=num_classes)
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint["state_dict"])
    model.eval()  
    return model

def preprocess_image(image_path):
    my_transforms = transforms.Compose([
        transforms.Resize((32, 32)),    
        transforms.ToTensor(),           
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  
    ])
    image = Image.open(image_path).convert('RGB')  
    return my_transforms(image).unsqueeze(0)  

def predict(image_path, model, class_names):
    input_tensor = preprocess_image(image_path)
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    input_tensor = input_tensor.to(device)

    with torch.no_grad():
        outputs = model(input_tensor)
        _, predicted_class = outputs.max(1)  
    
    return class_names[predicted_class.item()], predicted_class.item()


# model
checkpoint_path = "my_checkpoint.pth.tar"

for i in range(1,1000):
    # image we want to predict
    image_path = f"datafile/train_images/train_images/{i}.jpg"

    # load classes
    class_dictionary = np.load("datafile/class_names.npy", allow_pickle=True).item()
    class_names = list(class_dictionary.keys())
    class_names = [name.split('.', 1)[1] for name in class_names]

    # load model with corect weights
    model = load_model(checkpoint_path, num_classes=len(class_names))

    # predict image: obtain class and class number - 1
    predicted_class, predicted_class_number = predict(image_path, model, class_names)

    print(f"Predicted Class: {predicted_class} classified as: {predicted_class_number + 1}")
# Out:
# C:\Users\TWTNi\AppData\Local\Temp\ipykernel_43940\2923719215.py:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Black_footed_Albatross classified as: 1
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Nighthawk classified as: 92
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Laysan_Albatross classified as: 2
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Sooty_Albatross classified as: 3
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Groove_billed_Ani classified as: 4
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Crested_Auklet classified as: 5
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Least_Auklet classified as: 6
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Rhinoceros_Auklet classified as: 8
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Parakeet_Auklet classified as: 7
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Brewer_Blackbird classified as: 9
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Red_winged_Blackbird classified as: 10
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Rusty_Blackbird classified as: 11
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Long_tailed_Jaeger classified as: 71
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Yellow_headed_Blackbird classified as: 12
# Predicted Class: Bobolink classified as: 13
# Predicted Class: White_necked_Raven classified as: 108
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Boat_tailed_Grackle classified as: 49
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Bobolink classified as: 13
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Indigo_Bunting classified as: 14
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Lazuli_Bunting classified as: 15
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Painted_Bunting classified as: 16
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Cardinal classified as: 17
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Spotted_Catbird classified as: 18
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Gray_Catbird classified as: 19
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Bay_breasted_Warbler classified as: 158
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Yellow_breasted_Chat classified as: 20
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Eastern_Towhee classified as: 21
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Chuck_will_Widow classified as: 22
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Brandt_Cormorant classified as: 23
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Red_faced_Cormorant classified as: 24
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Pelagic_Cormorant classified as: 25
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Bronzed_Cowbird classified as: 26
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Shiny_Cowbird classified as: 27
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: Brown_Creeper classified as: 28
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: American_Crow classified as: 29
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Fish_Crow classified as: 30
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Black_billed_Cuckoo classified as: 31
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Mangrove_Cuckoo classified as: 32
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Scissor_tailed_Flycatcher classified as: 41
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
# Predicted Class: Yellow_billed_Cuckoo classified as: 33
